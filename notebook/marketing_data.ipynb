# %%
import pandas as pd
import sys
import os
from sqlalchemy import text
import pandas as pd
import numpy as np
# Menambahkan folder project ke sys.path
sys.path.append(os.path.abspath(os.path.join('..')))
from src.validation.validate_data import validation_process

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv('../data_source/marketing_data/ElectronicsProductsPricingData - ElectronicsProductsPricingData.csv')
data_name = 'marketing_data'
df.head()
# Out:
#                      id  prices.amountMax  prices.amountMin  \
# 0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4  AVpgMuGwLJeJML43KY_c             66.99             66.99
#
#   prices.availability prices.condition prices.currency  \
# 0                 Yes              New             USD
# 1            In Stock              New             USD
# 2            In Stock              New             USD
# 3                 Yes              New             USD
# 4                 Yes              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                               2017-12-14T06:00:00Z           True
# ...

# %% [markdown]
# # Data validasi

# %% [markdown]
# ## Cek Shape data

# %%
def check_shape_data(df,nama_tabel):
    rows_amount = df.shape[0]
    columns_amount = df.shape[1]

    print(f'Data {nama_tabel} has {rows_amount} rows and {columns_amount} columns')

check_shape_data(df,data_name)
# Out:
# Data marketing_data has 7249 rows and 31 columns

# %% [markdown]
# ## Cek tipe data

# %%
def check_type_data(df, table_name):
    print(f'Each column in `{table_name}` has the following data types:\n')
    for column in df.columns:
        print(f'Column `{column}` has data type `{df[column].dtype}`')

check_type_data(df, data_name)
# Out:
# Each column in `marketing_data` has the following data types:
#
# Column `id` has data type `object`
# Column `prices.amountMax` has data type `float64`
# Column `prices.amountMin` has data type `float64`
# Column `prices.availability` has data type `object`
# Column `prices.condition` has data type `object`
# Column `prices.currency` has data type `object`
# Column `prices.dateSeen` has data type `object`
# Column `prices.isSale` has data type `bool`
# Column `prices.merchant` has data type `object`
# Column `prices.shipping` has data type `object`
# Column `prices.sourceURLs` has data type `object`
# Column `asins` has data type `object`
# Column `brand` has data type `object`
# Column `categories` has data type `object`
# Column `dateAdded` has data type `object`
# Column `dateUpdated` has data type `object`
# Column `ean` has data type `object`
# Column `imageURLs` has data type `object`
# Column `keys` has data type `object`
# Column `manufacturer` has data type `object`
# ...

# %% [markdown]
# ## Check missing value

# %%
def check_missing_values(df, table_name):
    print(f'Each column in `{table_name}` has the following number of missing values:\n')
    for column in df.columns:
        missing_values = df[column].isnull().sum()
        percentage_missing_values = round(missing_values/len(df)*100,1)
        print(f'Column `{column}` has {missing_values} or {percentage_missing_values}% missing values')

check_missing_values(df, data_name)
# Out:
# Each column in `marketing_data` has the following number of missing values:
#
# Column `id` has 0 or 0.0% missing values
# Column `prices.amountMax` has 0 or 0.0% missing values
# Column `prices.amountMin` has 0 or 0.0% missing values
# Column `prices.availability` has 0 or 0.0% missing values
# Column `prices.condition` has 0 or 0.0% missing values
# Column `prices.currency` has 0 or 0.0% missing values
# Column `prices.dateSeen` has 0 or 0.0% missing values
# Column `prices.isSale` has 0 or 0.0% missing values
# Column `prices.merchant` has 0 or 0.0% missing values
# Column `prices.shipping` has 2972 or 41.0% missing values
# Column `prices.sourceURLs` has 0 or 0.0% missing values
# Column `asins` has 0 or 0.0% missing values
# Column `brand` has 0 or 0.0% missing values
# Column `categories` has 0 or 0.0% missing values
# Column `dateAdded` has 0 or 0.0% missing values
# Column `dateUpdated` has 0 or 0.0% missing values
# Column `ean` has 5706 or 78.7% missing values
# ...

# %% [markdown]
# ## Check duplicate

# %%
def check_duplicates(df, table_name):
    duplicate_count = len(df[df.duplicated()])
    print(f"`{table_name}` has {duplicate_count} duplicate entries")

check_duplicates(df, data_name)
# Out:
# `marketing_data` has 0 duplicate entries

# %% [markdown]
# ## Check unique values

# %%
def check_unique_values(df,table_name):
    print(f'Each column in `{table_name}` has the following number of missing values:\n')
    for column in df.columns:
        unique_values = df[column].unique()
        if len(unique_values)<=50:
            print(f'''Jumlah unique values pada kolom `{column} `adalah sebanyak : {len(unique_values)} yaitu : \n {unique_values}\n''')
        else:
            print(f'''Jumlah unique values pada kolom `{column}` adalah sebanyak : {len(unique_values)}\n''')

check_unique_values(df, data_name)
# Out:
# Each column in `marketing_data` has the following number of missing values:
#
# Jumlah unique values pada kolom `id` adalah sebanyak : 835
#
# Jumlah unique values pada kolom `prices.amountMax` adalah sebanyak : 2519
#
# Jumlah unique values pada kolom `prices.amountMin` adalah sebanyak : 2668
#
# Jumlah unique values pada kolom `prices.availability `adalah sebanyak : 14 yaitu :
#  ['Yes' 'In Stock' 'TRUE' 'undefined' 'yes' 'Out Of Stock' 'Special Order'
#  'No' 'More on the Way' 'sold' 'FALSE' 'Retired' '32 available'
#  '7 available']
#
# Jumlah unique values pada kolom `prices.condition `adalah sebanyak : 11 yaitu :
#  ['New' 'new' 'Seller refurbished' 'Used' 'pre-owned' 'Refurbished'
#  'Manufacturer refurbished' 'New other (see details)' 'refurbished'
# ...

# %% [markdown]
# ## Wrapped all Validations

# %%
validation_process(df, data_name)
# Out:
# ========== Start marketing_data Pipeline Validation ==========
# CHECKING SHAPE DATA
# Data marketing_data has 7249 rows and 31 columns
#
# CHECKING DATA TYPE
# Each column in marketing_data has the following data types:
#
# Column `id` has data type object
# Column `prices.amountMax` has data type float64
# Column `prices.amountMin` has data type float64
# Column `prices.availability` has data type object
# Column `prices.condition` has data type object
# Column `prices.currency` has data type object
# Column `prices.dateSeen` has data type object
# Column `prices.isSale` has data type bool
# Column `prices.merchant` has data type object
# Column `prices.shipping` has data type object
# Column `prices.sourceURLs` has data type object
# Column `asins` has data type object
# Column `brand` has data type object
# Column `categories` has data type object
# Column `dateAdded` has data type object
# Column `dateUpdated` has data type object
# Column `ean` has data type object
# ...

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Handle Incosistent data Value

# %%
import re
import numpy as np

def cleaning_unique_values_prices_availability(prices_availability):
    prices_availability = prices_availability.upper()
    yes_availabilty = ['YES','TRUE','SPECIAL ORDER','IN STOCK','32 AVAILABLE','7 AVAILABLE']
    no_availabilty = ['UNDEFINED','OUT OF STOCK','NO','MORE ON THE WAY','SOLD','FALSE','RETIRED']

    if prices_availability in yes_availabilty:
        return 'YES'
    elif prices_availability in no_availabilty :
        return 'NO'
    
    return prices_availability

def convert_to_pounds(weight_str):
    try:
        pounds = 0
        ounces = 0

        # Conversion factors
        ounces_to_pounds = 1 / 16
    
        
        # Find pounds or lbs (only take the first occurrence)
        pounds_match = re.search(r'(\d*\.?\d+)\s?(?:lbs?|pounds?)', weight_str)
        if pounds_match:
            pounds = float(pounds_match.group(1))
        
        # Find ounces values
        ounces_matches = re.search(r'(\d*\.?\d+)\s?(?:oz|ounces?)', weight_str)
        if ounces_matches:
            ounces = float(ounces_matches.group(1))
        
        # Convert ounces to pounds and sum
        total_pounds = pounds + (ounces * ounces_to_pounds)
        return total_pounds
    except:
        return np.NaN

## Handle Incosistent data Value
# Apply each function to the column
df['weightInPounds'] = df['weight'].apply(convert_to_pounds)
df['prices.availability'] = df['prices.availability'].apply(cleaning_unique_values_prices_availability)
df['prices.condition'] = df['prices.condition'].str.upper().str.replace('NEW OTHER (SEE DETAILS)','NEW')
df = df[~(df['prices.condition'].isin(list(df['prices.condition'].unique()[-2:])))]
df['prices.shipping'] = df['prices.shipping'].fillna('free').apply(lambda x: 0 if 'USD' not in x else x.replace('USD','').replace('.','')).astype('int')
df = df.rename(columns={'id':'product_id'})
# Drop unknown and 'weight' columns
for col in df.columns:
    if 'UNNAMED' in col.upper():
        df = df.drop(col, axis=1)
    if col.upper()=='WEIGHT':
        df = df.drop(col,axis=1)

## Handling missing values
# fill missing value in column manufacturer
df['manufacturer'] = df['manufacturer'].fillna('No Information')
# Mengubah kolom menjadi datetime
df['dateAdded'] = pd.to_datetime(df['dateAdded'])
df['dateUpdated'] = pd.to_datetime(df['dateUpdated'])

# Drop because missing value > 75%
df = df.drop('ean',axis=1)

# %% [markdown]
# ## Rename the columns

# %%
# Rename columns if "." in column , change to "_"
rename_columns = {}

for column in df.columns:
    if '.' in column:
        rename_columns[column] = '_'.join(column.split('.'))

df = df.rename(columns=rename_columns)

# Ubah nama kolom dari camelCase ke snake_case
# Fungsi untuk mengubah camelCase ke snake_case
def camel_to_snake(column_name):
    # Ganti 'URLs' dengan 'urls'
    column_name = re.sub(r'RLs', 'rls', column_name)
    # Konversi camelCase ke snake_case
    return re.sub(r'(?<!^)(?=[A-Z])', '_', column_name).lower()

# Mengubah nama kolom dengan rename() menggunakan fungsi camel_to_snake
df = df.rename(columns=camel_to_snake)
df.columns
# Out:
# Index(['product_id', 'prices_amount_max', 'prices_amount_min',
#        'prices_availability', 'prices_condition', 'prices_currency',
#        'prices_date_seen', 'prices_is_sale', 'prices_merchant',
#        'prices_shipping', 'prices_source_urls', 'asins', 'brand', 'categories',
#        'date_added', 'date_updated', 'image_urls', 'keys', 'manufacturer',
#        'manufacturer_number', 'name', 'primary_categories', 'source_urls',
#        'upc', 'weight_in_pounds'],
#       dtype='object')

# %% [markdown]
# # Handling missing values

# %% [markdown]
# # CHECK VALIDATION AGAIN

# %%
df[['dateAdded','dateUpdated']]
# Out:
#                      dateAdded               dateUpdated
# 0    2015-04-13 12:00:51+00:00 2018-05-12 18:59:48+00:00
# 1    2015-05-18 14:14:56+00:00 2018-06-13 19:39:02+00:00
# 2    2015-05-18 14:14:56+00:00 2018-06-13 19:39:02+00:00
# 3    2015-05-18 14:14:56+00:00 2018-06-13 19:39:02+00:00
# 4    2015-05-18 14:14:56+00:00 2018-06-13 19:39:02+00:00
# ...                        ...                       ...
# 7244 2016-06-10 18:41:15+00:00 2018-06-13 20:13:06+00:00
# 7245 2016-06-10 18:41:15+00:00 2018-06-13 20:13:06+00:00
# 7246 2016-06-10 18:41:15+00:00 2018-06-13 20:13:06+00:00
# 7247 2016-06-10 18:41:15+00:00 2018-06-13 20:13:06+00:00
# 7248 2016-06-10 18:41:15+00:00 2018-06-13 20:13:06+00:00
#
# [7246 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7246 entries, 0 to 7248
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           7246 non-null   object
#  1   prices_amount_max    7246 non-null   float64
#  2   prices_amount_min    7246 non-null   float64
#  3   prices_availability  7246 non-null   object
#  4   prices_condition     7246 non-null   object
#  5   prices_currency      7246 non-null   object
#  6   prices_date_seen     7246 non-null   object
#  7   prices_is_sale       7246 non-null   bool
#  8   prices_merchant      7246 non-null   object
#  9   prices_shipping      7246 non-null   int32
#  10  prices_source_urls   7246 non-null   object
#  11  asins                7246 non-null   object
#  12  brand                7246 non-null   object
#  13  categories           7246 non-null   object
#  14  date_added           7246 non-null   datetime64[ns, UTC]
# ...

# %%
validation_process(df,'marketing_data')
# Out:
# ========== Start marketing_data Pipeline Validation ==========
# CHECKING SHAPE DATA
# Data marketing_data has 7246 rows and 25 columns
#
# CHECKING DATA TYPE
# Each column in marketing_data has the following data types:
#
# Column `id` has data type object
# Column `prices.amountMax` has data type float64
# Column `prices.amountMin` has data type float64
# Column `prices.availability` has data type object
# Column `prices.condition` has data type object
# Column `prices.currency` has data type object
# Column `prices.dateSeen` has data type object
# Column `prices.isSale` has data type bool
# Column `prices.merchant` has data type object
# Column `prices.shipping` has data type int32
# Column `prices.sourceURLs` has data type object
# Column `asins` has data type object
# Column `brand` has data type object
# Column `categories` has data type object
# Column `dateAdded` has data type object
# Column `dateUpdated` has data type object
# Column `imageURLs` has data type object
# ...
